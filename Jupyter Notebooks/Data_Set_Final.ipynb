# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_path = "../Outputs/Main_Data_Set_Cleaned.csv"
csv2_path = "../Outputs/Annual Census by City and Age.csv"

# %%
# Import the CSV into a pandas DataFrame
MainDF = pd.read_csv(csv_path)
CensusAgeDF = pd.read_csv(csv2_path)

# %%
MainDF.head(3)
# Out:
#       City    State        Country  2021 Pop. Estimate  Pop. Growth (%)  \
# 0   Denton    Texas  United States              148146              4.0
# 1   Conroe    Texas  United States               94400              4.0
# 2  Bozeman  Montana  United States               54539              3.0
#
#    Brewery ID                   Brewery Name Brewery Type  \
# 0         426            Armadillo Ale Works        micro
# 1         118  Southern Star Brewing Company        micro
# 2         219        Bozeman Brewing Company        micro
#
#    # Breweries in City                        Beer Style  ...  \
# 0                 10.0  American Double / Imperial Stout  ...
# 1                  3.0           American Pale Ale (APA)  ...
# 2                 10.0                   American Porter  ...
#
#    Basic Utilities Internet  1bd Apt. (City Center)  \
# 0           162.23   60.430                  960.00
# 1           266.46  108.960                 1271.25
# ...

# %%
CensusAgeDF.head()
# Out:
#                       City     State  % Age Over 19
# 0                  Abilene     Texas       0.727664
# 1                    Akron      Ohio       0.770492
# 2                   Albany   Georgia       0.729200
# 3           Albany-Lebanon    Oregon       0.756791
# 4  Albany-Schenectady-Troy  New York       0.776919

# %%
FinalDF = pd.merge(MainDF, CensusAgeDF, on=["City", "State"])

# %%
FinalDF
# Out:
#               City           State        Country  2021 Pop. Estimate  \
# 0          Bozeman         Montana  United States               54539
# 1             Bend          Oregon  United States              102059
# 2             Bend          Oregon  United States              102059
# 3             Bend          Oregon  United States              102059
# 4       Bellingham      Washington  United States               92289
# 5       Huntsville         Alabama  United States              216963
# 6    Oklahoma City        Oklahoma  United States              687725
# 7    Oklahoma City        Oklahoma  United States              687725
# 8         Missoula         Montana  United States               74822
# 9          Greeley        Colorado  United States              109323
# 10        Savannah         Georgia  United States              147088
# 11        Columbus            Ohio  United States              906528
# ...

# %%
FinalDF = FinalDF[['City', 'State','% Age Over 19','# Breweries in City','2021 Pop. Estimate']]

# %%
FinalDF
# Out:
#               City           State  % Age Over 19  # Breweries in City  \
# 0          Bozeman         Montana       0.771508                 10.0
# 1             Bend          Oregon       0.787833                 30.0
# 2             Bend          Oregon       0.787833                 30.0
# 3             Bend          Oregon       0.787833                 30.0
# 4       Bellingham      Washington       0.778859                 15.0
# 5       Huntsville         Alabama       0.758209                  9.0
# 6    Oklahoma City        Oklahoma       0.730130                 14.0
# 7    Oklahoma City        Oklahoma       0.730130                 14.0
# 8         Missoula         Montana       0.785632                 10.0
# 9          Greeley        Colorado       0.714595                  7.0
# 10        Savannah         Georgia       0.744666                  6.0
# 11        Columbus            Ohio       0.739540                 39.0
# ...

# %%
# Reorder Columns 
FinalDF = FinalDF[['City','State','2021 Pop. Estimate', '% Age Over 19','# Breweries in City']]

# %%
FinalDF.drop_duplicates(inplace=True)
# Out:
# C:\Users\Nithin\AppData\Local\Temp\ipykernel_4240\1268566477.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FinalDF.drop_duplicates(inplace=True)

# %%
FinalDF['People Per Brewery'] = (FinalDF['2021 Pop. Estimate'] * FinalDF['% Age Over 19']) / FinalDF['# Breweries in City']
FinalDF
# Out:
# C:\Users\Nithin\AppData\Local\Temp\ipykernel_4240\1478929110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FinalDF['People Per Brewery'] = (FinalDF['2021 Pop. Estimate'] * FinalDF['% Age Over 19']) / FinalDF['# Breweries in City']
#               City           State  2021 Pop. Estimate  % Age Over 19  \
# 0          Bozeman         Montana               54539       0.771508
# 1             Bend          Oregon              102059       0.787833
# 4       Bellingham      Washington               92289       0.778859
# 5       Huntsville         Alabama              216963       0.758209
# 6    Oklahoma City        Oklahoma              687725       0.730130
# 8         Missoula         Montana               74822       0.785632
# ...

# %%
FinalDF = FinalDF.sort_values(['People Per Brewery'],ascending=False)[:10]
FinalDF
# Out:
#              City       State  2021 Pop. Estimate  % Age Over 19  \
# 41    Baton Rouge   Louisiana              222185       0.738894
# 6   Oklahoma City    Oklahoma              687725       0.730130
# 28   Jacksonville     Florida              954614       0.755015
# 32         Tucson     Arizona              543242       0.767457
# 5      Huntsville     Alabama              216963       0.758209
# 10       Savannah     Georgia              147088       0.744666
# 13     Eau Claire   Wisconsin               69441       0.759625
# 11       Columbus        Ohio              906528       0.739540
# 20    Gainesville     Florida              140398       0.769842
# 23    Albuquerque  New Mexico              562599       0.761592
#
#     # Breweries in City  People Per Brewery
# 41                  3.0        54723.689441
# 6                  14.0        35866.341847
# 28                 21.0        34321.317094
# 32                 19.0        21942.893959
# ...

# %%
# Set x axis and tick locations
x_axis = FinalDF['City']

# %%
ticks = [ x for x in x_axis]

# %%
plt.bar(x_axis , FinalDF["People Per Brewery"], color = 'red', alpha=.75, align="center")
plt.xticks(np.arange(len(FinalDF)), rotation=45)
plt.xlabel("Cities in US")
plt.ylabel("Number of People over Age 20 Per Brewery")
plt.title("People over Age 20 Per Brewery in Cities (US)")
plt.show()
plt.tight_layout()
